# %% [markdown]
# ### Instructions on ffmpeg upgrades in Colab
# ffmpeg 4.4.0 does not support dialoguenhance and speechnorm filters => need versions above 6
#
# Credit: https://github.com/dropcreations/FFmpeg-in-Google-Colab/tree/main

# %%
# Download the latest compiled binaries for linux64
# !sudo curl -L https://github.com/BtbN/FFmpeg-Builds/releases/download/latest/ffmpeg-master-latest-linux64-gpl.tar.xz -o /usr/local/bin/ffmpeg.tar.xz

# %%
# unzip directly to the /bin/ folder; hence, change curdir
# %cd /usr/local/bin/
!7z e /usr/local/bin/ffmpeg.tar.xz
!7z e /usr/local/bin/ffmpeg.tar
# !sudo chmod a+rx /usr/local/bin/ffmpeg

# %%
# change curdir back to /content/ when done:
# %cd /content/

# %%
# Process files in the working directory
# !export file="file.MP3" && ffmpeg -i "$file" -af "dialoguenhance=enhance=3,speechnorm" -ar 16000 -ac 1 "${file%.MP3}.WAV"
